# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading dataset

# %%
df = pd.read_csv("C:/Users/HP/OneDrive/Desktop/Datasets/hotel_booking.csv")

# %% [markdown]
# # EDA and data cleaning

# %%
df.head(7)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
# ...

# %%
df["is_canceled"].sum()
# Out:
# 44224

# %%
df["lead_time"].sum()
# Out:
# 12417923

# %%
df["is_canceled"].isnull().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (119390, 36)

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df.describe(include = 'object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status             name  \
# count        119390        119390             119390           119390
# unique            3             4                  3            81503
# top      No Deposit     Transient          Check-Out  Michael Johnson
# ...

# %%
for col in df.describe(include= 'object').columns:
    print(col)
    print(df[col].unique())
    print('_'*50)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# __________________________________________________
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# __________________________________________________
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# __________________________________________________
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.drop(['company','agent'], axis = 1 , inplace = True)

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# std         0.483168     106.903309           0.707459
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# std                   13.589971                   8.780324
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df['adr'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df = df[df['adr']<5000]

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118897.000000  118897.000000      118897.000000
# mean        0.371347     104.312018        2016.157657
# std         0.483167     106.903570           0.707462
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118897.000000              118897.000000
# mean                  27.166674                  15.800802
# std                   13.589966                   8.780321
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# # Data Analysis and Visualization

# %%
cancelled_perc = df['is_canceled'].value_counts(normalize = True)
print(cancelled_perc)

plt.figure(figsize = (5,4))
plt.title ('Reservation status count')
plt.bar(['Not cancelled' , 'Cancelled'],df['is_canceled'].value_counts(), edgecolor = 'k' , width = 0.7)
plt.show()
# Out:
# 0    0.628653
# 1    0.371347
# Name: is_canceled, dtype: float64

# %%
# import matplotlib.pyplot as plt

cancelled_counts = df['is_canceled'].value_counts()

# Create a bar plot
plt.figure(figsize=(4, 5))  
ax = cancelled_counts.plot(kind='bar')
plt.title('Cancellation Counts by Category')
plt.xlabel('Cancellation Status')
plt.ylabel('Count')
plt.xticks(rotation=0) 
# plt.yticks(rotation=90) 

# Adding labels to the bars
for index, value in enumerate(cancelled_counts):
    plt.text(index, value, str(value), ha='center', va='bottom')

# Adding labels for 'cancelled' and 'not cancelled'
ax.set_xticklabels(['Not Cancelled', 'Cancelled'])

plt.show()  # Display the plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 4))
ax1 = sns.countplot(x='hotel', hue='is_canceled', data=df, palette='Blues')

# Get the handles and labels for the legend
legend_labels, _ = ax1.get_legend_handles_labels()

# Create custom legend handles with labels and matching colors
custom_legend = [
    plt.Line2D([0], [0], color='blue', lw=3),
    plt.Line2D([0], [0], color='orange', lw=3)
]
legend_labels = ['Not Canceled', 'Canceled']

# Create the legend with custom handles and labels
ax1.legend(custom_legend, legend_labels, title="Cancellation Status", loc="upper right")

plt.title("Reservation status in different hotels", size=20)
plt.xlabel("Hotel")
plt.ylabel("Number of Reservations")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define custom colors for the 'Canceled' and 'Not Canceled' bars
custom_colors = ["blue", "orange"]

plt.figure(figsize=(8, 4))
ax1 = sns.countplot(x='hotel', hue='is_canceled', data=df, palette=custom_colors)

# Get the handles and labels for the legend
legend_labels, _ = ax1.get_legend_handles_labels()

# Create custom legend handles with labels
custom_legend = [plt.Line2D([0], [0], color='blue', lw=3),
                 plt.Line2D([0], [0], color='orange', lw=3)]
legend_labels = ['Not Canceled', 'Canceled']

# Create the legend with custom handles and labels
ax1.legend(custom_legend, legend_labels, title="Cancellation Status", loc="upper right")

plt.title("Reservation status in different hotels", size=20)
plt.xlabel("Hotel")
plt.ylabel("Number of Reservations")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define custom colors for the 'Canceled' and 'Not Canceled' bars
custom_colors = ["blue", "orange"]

plt.figure(figsize=(8, 4))
ax1 = sns.countplot(x='hotel', hue='is_canceled', data=df, palette=custom_colors)

# Get the handles and labels for the legend
legend_labels, _ = ax1.get_legend_handles_labels()

# Create custom legend handles with labels
custom_legend = [plt.Line2D([0], [0], color='blue', lw=3),
                 plt.Line2D([0], [0], color='orange', lw=3)]
legend_labels = ['Not Canceled', 'Canceled']

# Create the legend with custom handles and labels
ax1.legend(custom_legend, legend_labels, title="Cancellation Status", loc="upper right")

plt.title("Reservation status in different hotels", size=20)
plt.xlabel("Hotel")
plt.ylabel("Number of Reservations")

# Add labels with values on top of the bars
for p in ax1.patches:
    ax1.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', fontsize=10, color='black', xytext=(0, 5), textcoords='offset points')

plt.show()

# %% [markdown]
# ### percentage of how many reservations are cancelled

# %%
resort_hotel = df[df['hotel'] == "Resort Hotel"]
resort_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# 0    0.72025
# 1    0.27975
# Name: is_canceled, dtype: float64

# %%
City_hotel = df[df['hotel'] == "City Hotel"]
City_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# 0    0.582918
# 1    0.417082
# Name: is_canceled, dtype: float64

# %%
import pandas as pd

# Filter for City Hotel
city_hotel = df[df['hotel'] == "City Hotel"]

# Calculate the average daily rate for City Hotel
average_daily_rate_city = city_hotel['adr'].mean()

# Filter for Resort Hotel
resort_hotel = df[df['hotel'] == "Resort Hotel"]

# Calculate the average daily rate for Resort Hotel
average_daily_rate_resort = resort_hotel['adr'].mean()

print("Average Daily Rate for City Hotel:", average_daily_rate_city)
print("Average Daily Rate for Resort Hotel:", average_daily_rate_resort)
# Out:
# Average Daily Rate for City Hotel: 105.25970340853203
# Average Daily Rate for Resort Hotel: 95.34755505606628

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
plt.title("Average Daily Rate in City and Resort Hotel", fontsize=30)

# Assuming you have defined 'resort_hotel' and 'city_hotel' DataFrames
plt.plot(resort_hotel.index, resort_hotel['adr'], label="Resort Hotel")
plt.plot(city_hotel.index, city_hotel['adr'], label="City Hotel")

plt.legend(fontsize=20)
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming you have defined 'resort_hotel' and 'city_hotel' DataFrames
plt.figure(figsize=(12, 6))
plt.title("Average Daily Rate by Day", fontsize=16)

# Create a scatter plot for Resort Hotel
plt.scatter(resort_hotel.index, resort_hotel['adr'], label="Resort Hotel", color="royalblue", s=10, alpha=0.7)

# Create a scatter plot for City Hotel
plt.scatter(city_hotel.index, city_hotel['adr'], label="City Hotel", color="coral", s=10, alpha=0.7)

# Customize the tick label font size
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Add labels to the axes
plt.xlabel("Day", fontsize=14)
plt.ylabel("Average Daily Rate", fontsize=14)

# Add a legend
plt.legend(fontsize=12)

# Show the plot
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
cancelled_data =  df[df['is_canceled'] == 1 ]
top_10_country = cancelled_data['country'].value_counts()[:10]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named df
top_10_canceled_countries = df[df['is_canceled'] == 1]['country'].value_counts().head(10)

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_10_canceled_countries, labels=top_10_canceled_countries.index, autopct='%1.1f%%', startangle=140)

plt.title('Top 10 Countries with the Most Canceled Reservations')
plt.axis('equal')  # Equal aspect ratio ensures that the pie chart is circular.

plt.show()

# %%
df['market_segment'].value_counts()
# Out:
# Online TA        56402
# Offline TA/TO    24159
# Groups           19806
# Direct           12448
# Corporate         5111
# Complementary      734
# Aviation           237
# Name: market_segment, dtype: int64

# %% [markdown]
# #### To see the percentage

# %%
df['market_segment'].value_counts(normalize = True)
# Out:
# Online TA        0.474377
# Offline TA/TO    0.203193
# Groups           0.166581
# Direct           0.104696
# Corporate        0.042987
# Complementary    0.006173
# Aviation         0.001993
# Name: market_segment, dtype: float64

# %%
cancelled_data['market_segment'].value_counts(normalize=True)
# Out:
# Online TA        0.469696
# Groups           0.273985
# Offline TA/TO    0.187466
# Direct           0.043486
# Corporate        0.022151
# Complementary    0.002038
# Aviation         0.001178
# Name: market_segment, dtype: float64

# %%
print(df['is_canceled'])
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 119385    0
# 119386    0
# 119387    0
# 119388    0
# 119389    0
# Name: is_canceled, Length: 118897, dtype: int64

# %%
cancelled_df_adr = cancelled_data.groupby('reservation_status_date')[['adr']].mean()
cancelled_df_adr.reset_index(inplace=True)
cancelled_df_adr.sort_values('reservation_status_date', inplace=True)

not_cancelled_data = df[df['is_canceled'] == 0]
not_cancelled_df_adr = not_cancelled_data.groupby('reservation_status_date')[['adr']].mean()
not_cancelled_df_adr.reset_index(inplace=True)
not_cancelled_df_adr.sort_values('reservation_status_date', inplace=True)

import matplotlib.pyplot as plt

plt.figure(figsize=(20, 6))
plt.title('Average Daily Rate')
plt.plot(not_cancelled_df_adr['reservation_status_date'], not_cancelled_df_adr['adr'], label='not cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'], cancelled_df_adr['adr'], label='cancelled')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 6
#       3 cancelled_df_adr.sort_values('reservation_status_date', inplace=True)
#       5 not_cancelled_data = df[df['is_canceled'] == 0]
# ----> 6 not_cancelled_df_adr = not_cancelled_data.groupby('reservation_status_date')[['adr']].mean()
#       7 not_cancelled_df_adr.reset_index(inplace=True)
#       8 not_cancelled_df_adr.sort_values('reservation_status_date', inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:8402, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8399     raise TypeError("You have to supply one of 'by' and 'level'")
#    8400 axis = self._get_axis_number(axis)
# -> 8402 return DataFrameGroupBy(
#    8403     obj=self,
#    8404     keys=by,
#    8405     axis=axis,
#    8406     level=level,
# ...

# %%
import matplotlib.pyplot as plt

# Assuming you have defined 'resort_hotel' and 'city_hotel' DataFrames
plt.figure(figsize=(12, 6))
plt.title("Average Daily Rate by Day", fontsize=16)

# Create a line plot for Resort Hotel
plt.plot(resort_hotel.index, resort_hotel['adr'], label="Resort Hotel", color="royalblue", linewidth=2)

# Create a line plot for City Hotel
plt.plot(city_hotel.index, city_hotel['adr'], label="City Hotel", color="coral", linewidth=2)

# Customize the tick label font size
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Add labels to the axes
plt.xlabel("Day", fontsize=14)
plt.ylabel("Average Daily Rate", fontsize=14)

# Add a legend
plt.legend(fontsize=12)

# Show the plot
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()
